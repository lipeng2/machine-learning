# %%
import pandas as pd
import numpy as np
from IPython.display import display
import os
import json
from pandas.io.json import json_normalize

pd.options.display.max_columns = None

# %%
def load_df(csv_path, nrows=None):
    JSON_COLUMNS = ['device', 'geoNetwork', 'totals', 'trafficSource']
    types = {
        "fullVisitorId": "str", # readme says it should be str
        "channelGrouping": "str",
        "date": "str",
        "socialEngagementType": "str",
        "visitId": "int32",
        "visitNumber": "int8",
        "visitStartTime": "int32",
    }
    
    df = pd.read_csv(csv_path, 
                     converters={column: json.loads for column in JSON_COLUMNS}, 
                     dtype=types,
                     nrows=nrows)
    
    for column in JSON_COLUMNS:
        column_as_df = json_normalize(df[column])
        column_as_df.columns = [f"{column}.{subcolumn}" for subcolumn in column_as_df.columns]
        df = df.drop(column, axis=1).merge(column_as_df, right_index=True, left_index=True)
        
    print(f"Loaded {os.path.basename(csv_path)}. Shape: {df.shape}")
    return df

# %%
df_raw = load_df('train_v2.csv', nrows=500000)
# Out:
# Loaded train_v2.csv. Shape: (500000, 60)

# %%
display(df_raw.head())
# Out:
#   channelGrouping                              customDimensions      date  \
# 0  Organic Search             [{'index': '4', 'value': 'EMEA'}]  20171016
# 1        Referral    [{'index': '4', 'value': 'North America'}]  20171016
# 2          Direct    [{'index': '4', 'value': 'North America'}]  20171016
# 3  Organic Search             [{'index': '4', 'value': 'EMEA'}]  20171016
# 4  Organic Search  [{'index': '4', 'value': 'Central America'}]  20171016
#
#          fullVisitorId                                               hits  \
# 0  3162355547410993243  [{'hitNumber': '1', 'time': '0', 'hour': '17',...
# 1  8934116514970143966  [{'hitNumber': '1', 'time': '0', 'hour': '10',...
# 2  7992466427990357681  [{'hitNumber': '1', 'time': '0', 'hour': '17',...
# 3  9075655783635761930  [{'hitNumber': '1', 'time': '0', 'hour': '9', ...
# 4  6960673291025684308  [{'hitNumber': '1', 'time': '0', 'hour': '14',...
#
#    socialEngagementType     visitId  visitNumber  visitStartTime  \
# 0  Not Socially Engaged  1508198450            1      1508198450
# 1  Not Socially Engaged  1508176307            6      1508176307
# 2  Not Socially Engaged  1508201613            1      1508201613
# 3  Not Socially Engaged  1508169851            1      1508169851
# 4  Not Socially Engaged  1508190552            1      1508190552
#
#   device.browser             device.browserSize  \
# 0        Firefox  not available in demo dataset
# 1         Chrome  not available in demo dataset
# 2         Chrome  not available in demo dataset
# 3         Chrome  not available in demo dataset
# 4         Chrome  not available in demo dataset
#
#            device.browserVersion device.deviceCategory  \
# 0  not available in demo dataset               desktop
# 1  not available in demo dataset               desktop
# 2  not available in demo dataset                mobile
# 3  not available in demo dataset               desktop
# 4  not available in demo dataset               desktop
#
#              device.flashVersion  device.isMobile  \
# 0  not available in demo dataset            False
# 1  not available in demo dataset            False
# 2  not available in demo dataset             True
# 3  not available in demo dataset            False
# 4  not available in demo dataset            False
#
#                  device.language    device.mobileDeviceBranding  \
# 0  not available in demo dataset  not available in demo dataset
# 1  not available in demo dataset  not available in demo dataset
# 2  not available in demo dataset  not available in demo dataset
# 3  not available in demo dataset  not available in demo dataset
# 4  not available in demo dataset  not available in demo dataset
#
#          device.mobileDeviceInfo device.mobileDeviceMarketingName  \
# 0  not available in demo dataset    not available in demo dataset
# 1  not available in demo dataset    not available in demo dataset
# 2  not available in demo dataset    not available in demo dataset
# 3  not available in demo dataset    not available in demo dataset
# 4  not available in demo dataset    not available in demo dataset
#
#         device.mobileDeviceModel     device.mobileInputSelector  \
# 0  not available in demo dataset  not available in demo dataset
# 1  not available in demo dataset  not available in demo dataset
# 2  not available in demo dataset  not available in demo dataset
# 3  not available in demo dataset  not available in demo dataset
# 4  not available in demo dataset  not available in demo dataset
#
#   device.operatingSystem  device.operatingSystemVersion  \
# 0                Windows  not available in demo dataset
# 1              Chrome OS  not available in demo dataset
# 2                Android  not available in demo dataset
# 3                Windows  not available in demo dataset
# 4                Windows  not available in demo dataset
#
#              device.screenColors        device.screenResolution  \
# 0  not available in demo dataset  not available in demo dataset
# 1  not available in demo dataset  not available in demo dataset
# 2  not available in demo dataset  not available in demo dataset
# 3  not available in demo dataset  not available in demo dataset
# 4  not available in demo dataset  not available in demo dataset
#
#                  geoNetwork.city              geoNetwork.cityId  \
# 0  not available in demo dataset  not available in demo dataset
# 1                      Cupertino  not available in demo dataset
# 2  not available in demo dataset  not available in demo dataset
# 3  not available in demo dataset  not available in demo dataset
# 4  not available in demo dataset  not available in demo dataset
#
#   geoNetwork.continent geoNetwork.country            geoNetwork.latitude  \
# 0               Europe            Germany  not available in demo dataset
# 1             Americas      United States  not available in demo dataset
# 2             Americas      United States  not available in demo dataset
# 3                 Asia             Turkey  not available in demo dataset
# 4             Americas             Mexico  not available in demo dataset
#
#             geoNetwork.longitude                   geoNetwork.metro  \
# 0  not available in demo dataset      not available in demo dataset
# 1  not available in demo dataset  San Francisco-Oakland-San Jose CA
# 2  not available in demo dataset      not available in demo dataset
# 3  not available in demo dataset      not available in demo dataset
# 4  not available in demo dataset      not available in demo dataset
#
#   geoNetwork.networkDomain     geoNetwork.networkLocation  \
# 0                (not set)  not available in demo dataset
# 1                (not set)  not available in demo dataset
# 2      windjammercable.net  not available in demo dataset
# 3          unknown.unknown  not available in demo dataset
# 4    prod-infinitum.com.mx  not available in demo dataset
#
#                geoNetwork.region geoNetwork.subContinent totals.bounces  \
# 0  not available in demo dataset          Western Europe              1
# 1                     California        Northern America            NaN
# 2  not available in demo dataset        Northern America            NaN
# 3  not available in demo dataset            Western Asia            NaN
# 4  not available in demo dataset         Central America            NaN
#
#   totals.hits totals.newVisits totals.pageviews totals.sessionQualityDim  \
# 0           1                1                1                        1
# 1           2              NaN                2                        2
# 2           2                1                2                        1
# 3           2                1                2                        1
# 4           2                1                2                        1
#
#   totals.timeOnSite totals.totalTransactionRevenue totals.transactionRevenue  \
# 0               NaN                            NaN                       NaN
# 1                28                            NaN                       NaN
# 2                38                            NaN                       NaN
# 3                 1                            NaN                       NaN
# 4                52                            NaN                       NaN
#
#   totals.transactions totals.visits trafficSource.adContent  \
# 0                 NaN             1                     NaN
# 1                 NaN             1                     NaN
# 2                 NaN             1                     NaN
# 3                 NaN             1                     NaN
# 4                 NaN             1                     NaN
#
#   trafficSource.adwordsClickInfo.adNetworkType  \
# 0                                          NaN
# 1                                          NaN
# 2                                          NaN
# 3                                          NaN
# 4                                          NaN
#
#   trafficSource.adwordsClickInfo.criteriaParameters  \
# 0                     not available in demo dataset
# 1                     not available in demo dataset
# 2                     not available in demo dataset
# 3                     not available in demo dataset
# 4                     not available in demo dataset
#
#   trafficSource.adwordsClickInfo.gclId  \
# 0                                  NaN
# 1                                  NaN
# 2                                  NaN
# 3                                  NaN
# 4                                  NaN
#
#   trafficSource.adwordsClickInfo.isVideoAd  \
# 0                                      NaN
# 1                                      NaN
# 2                                      NaN
# 3                                      NaN
# 4                                      NaN
#
#   trafficSource.adwordsClickInfo.page trafficSource.adwordsClickInfo.slot  \
# 0                                 NaN                                 NaN
# 1                                 NaN                                 NaN
# 2                                 NaN                                 NaN
# 3                                 NaN                                 NaN
# 4                                 NaN                                 NaN
#
#   trafficSource.campaign trafficSource.campaignCode  \
# 0              (not set)                        NaN
# 1              (not set)                        NaN
# 2              (not set)                        NaN
# 3              (not set)                        NaN
# 4              (not set)                        NaN
#
#   trafficSource.isTrueDirect trafficSource.keyword trafficSource.medium  \
# 0                        NaN          water bottle              organic
# 1                        NaN                   NaN             referral
# 2                       True                   NaN               (none)
# 3                        NaN        (not provided)              organic
# 4                        NaN        (not provided)              organic
#
#                           trafficSource.referralPath trafficSource.source
# 0                                                NaN               google
# 1  /a/google.com/transportation/mtv-services/bike...     sites.google.com
# 2                                                NaN             (direct)
# 3                                                NaN               google
# 4                                                NaN               google

# %%
# drop columns that only have one value + customDimensions and hits
one_value_col = [c for c in df_raw.columns if df_raw[c].nunique(dropna=False)==1]
df_raw.drop(one_value_col+['customDimensions', 'hits'], axis=1, inplace=True)

# %%
df_test = load_df('test_v2.csv')
# Out:
# Loaded test_v2.csv. Shape: (401589, 59)

# %%
df_raw.drop(columns=['trafficSource.campaignCode'], inplace=True)
df_test.drop(one_value_col+["customDimensions", "hits"], axis=1, inplace=True)

# %%
tar = 'totals.transactionRevenue'
df_raw[tar].fillna(0, inplace=True)
df_raw[tar] = df_raw[tar].astype(float)
df_raw[tar] = np.log1p(df_raw[tar])

# %%
# helper functions pull from fastai library to help add datatime features

import re
def ifnone(a,b):
    "`a` if `a` is not None, otherwise `b`."
    return b if a is None else a

def make_date(df, date_field:str):
    "Make sure `df[field_name]` is of the right date type."
    field_dtype = df[date_field].dtype
    if isinstance(field_dtype, pd.core.dtypes.dtypes.DatetimeTZDtype):
        field_dtype = np.datetime64
    if not np.issubdtype(field_dtype, np.datetime64):
        df[date_field] = pd.to_datetime(df[date_field], infer_datetime_format=True)

def add_datepart(df, field_name, prefix=None, drop=True, time:bool=False):
    "Helper function that adds columns relevant to a date in the column `field_name` of `df`."
    make_date(df, field_name)
    field = df[field_name]
    prefix = ifnone(prefix, re.sub('[Dd]ate$', '', field_name))
    attr = ['Year', 'Month', 'Week', 'Day', 'Dayofweek', 'Dayofyear', 'Is_month_end', 'Is_month_start', 
            'Is_quarter_end', 'Is_quarter_start', 'Is_year_end', 'Is_year_start']
    if time: attr = attr + ['Hour', 'Minute', 'Second']
    for n in attr: df[prefix + n] = getattr(field.dt, n.lower())
    df[prefix + 'Elapsed'] = field.astype(np.int64) // 10 ** 9
    if drop: df.drop(field_name, axis=1, inplace=True)
    return df

# %%
df_raw["visitStartTime"] = pd.to_datetime(df_raw["visitStartTime"], infer_datetime_format=True, unit="s")
df_raw["date"] = pd.to_datetime(df_raw["date"], infer_datetime_format=True, format="%Y%m%d")
add_datepart(df_raw, 'date')
add_datepart(df_raw, 'visitStartTime')
# Out:
#        channelGrouping        fullVisitorId     visitId  visitNumber  \
# 0       Organic Search  3162355547410993243  1508198450            1
# 1             Referral  8934116514970143966  1508176307            6
# 2               Direct  7992466427990357681  1508201613            1
# 3       Organic Search  9075655783635761930  1508169851            1
# 4       Organic Search  6960673291025684308  1508190552            1
# 5             Referral  0166277907528479249  1508196701            1
# 6             Referral  8349655975937271469  1508152478            1
# 7       Organic Search  1332629902468998662  1508206208            1
# 8       Organic Search   632878546807742341  1508207516            1
# 9       Organic Search  1259490915281096752  1508165159            2
# 10      Organic Search  7390444353235629134  1508157285            1
# 11      Organic Search  1297236773919696722  1508160120            1
# 12      Organic Search  5983987899933814948  1508177658            1
# 13         Paid Search  6135613929977117121  1508166431           10
# 14      Organic Search  7058083259448191057  1508174145            1
# 15      Organic Search  9592294493127192752  1508197277            1
# 16      Organic Search  6338477365942527347  1508177911            1
# 25                 Chrome               desktop            False
# 26                 Chrome                mobile             True
# 27                 Chrome               desktop            False
# 28      Internet Explorer               desktop            False
# 29                 Chrome               desktop            False
# ...                   ...                   ...              ...
# 499970             Safari                mobile             True
# 499971            Firefox               desktop            False
# 499972             Chrome               desktop            False
# 499973  Internet Explorer               desktop            False
# 499974             Chrome               desktop            False
# 499975         Opera Mini                mobile             True
# 499976             Chrome                mobile             True
# 499977             Safari                mobile             True
# 499978             Safari                mobile             True
# 499979             Chrome                mobile             True
# 499980             Chrome                mobile             True
# 499981               Edge               desktop            False
# 499982             Chrome                mobile             True
# 499983             Chrome                mobile             True
# 499984             Chrome               desktop            False
# 499985             Chrome               desktop            False
# 499986             Safari               desktop            False
# 499987             Safari                mobile             True
# 499988             Chrome                mobile             True
# 499989             Safari                mobile             True
# 499990             Chrome                mobile             True
# 499991             Chrome                mobile             True
# 499992             Chrome                mobile             True
# 499993             Chrome                mobile             True
# 499994             Safari                mobile             True
# 499995             Safari                tablet             True
# 499996   Samsung Internet                mobile             True
# 499997             Chrome               desktop            False
# 499998             Chrome               desktop            False
# 499999             Chrome                mobile             True
#
#        device.operatingSystem                geoNetwork.city  \
# 0                     Windows  not available in demo dataset
# 1                   Chrome OS                      Cupertino
# 2                     Android  not available in demo dataset
# 3                     Windows  not available in demo dataset
# 4                     Windows  not available in demo dataset
# 5                   Macintosh                  San Francisco
# 6                   Macintosh                         London
# 7                     Windows  not available in demo dataset
# 8                   Macintosh                    Mexico City
# 9                         iOS  not available in demo dataset
# 10                  Chrome OS  not available in demo dataset
# 11                  Macintosh  not available in demo dataset
# 12                        iOS  not available in demo dataset
# 13                        iOS                      (not set)
# 14                    Windows  not available in demo dataset
# 15                  Macintosh  not available in demo dataset
# 16                    Android  not available in demo dataset
# 17                        iOS  not available in demo dataset
# 18                  Macintosh                        Ixelles
# 19                        iOS  not available in demo dataset
# 20                    Windows  not available in demo dataset
# 21                  Chrome OS  not available in demo dataset
# 22                    Windows  not available in demo dataset
# 23                  Macintosh  not available in demo dataset
# 24                        iOS                         Minato
# 25                      Linux  not available in demo dataset
# 26                    Android  not available in demo dataset
# 27                      Linux  not available in demo dataset
# 28                    Windows                    Los Angeles
# 29                    Windows                        Ixelles
# ...                       ...                            ...
# 499970                    iOS  not available in demo dataset
# 499971                Windows                        Seattle
# 499972                Windows  not available in demo dataset
# 499973                Windows  not available in demo dataset
# 499974                Windows  not available in demo dataset
# 499975                Android  not available in demo dataset
# 499976                Android  not available in demo dataset
# 499977                    iOS  not available in demo dataset
# 499978                    iOS                        Atlanta
# 499979                    iOS  not available in demo dataset
# 499980                Android  not available in demo dataset
# 499981                Windows  not available in demo dataset
# 499982                Android                        Chennai
# 499983                Android                      Bengaluru
# 499984                Windows  not available in demo dataset
# 499985                Windows                         Minato
# 499986              Macintosh  not available in demo dataset
# 499987                    iOS  not available in demo dataset
# 499988                Android                         Sydney
# 499989                    iOS                    San Antonio
# 499990                Android                      (not set)
# 499991                Android                       New York
# 499992                Android                          Paris
# 499993                Android  not available in demo dataset
# 499994                    iOS  not available in demo dataset
# 499995                    iOS                    Los Angeles
# 499996                Android  not available in demo dataset
# 499997              Macintosh  not available in demo dataset
# 499998                Windows  not available in demo dataset
# 499999                Android  not available in demo dataset
#
#        geoNetwork.continent geoNetwork.country  \
# 0                    Europe            Germany
# 1                  Americas      United States
# 2                  Americas      United States
# 3                      Asia             Turkey
# 4                  Americas             Mexico
# 5                  Americas      United States
# 6                    Europe     United Kingdom
# 7                    Europe            Denmark
# 8                  Americas             Mexico
# 9                    Europe        Netherlands
# 10                   Europe     United Kingdom
# 11                   Europe             Sweden
# 12                 Americas      United States
# 13                 Americas      United States
# 14                 Americas             Canada
# 15                   Europe     United Kingdom
# 16                     Asia              India
# 17                   Europe     United Kingdom
# 18                   Europe            Belgium
# 19                     Asia        Philippines
# 20                   Europe           Slovakia
# 21                   Europe     United Kingdom
# 22                   Europe     United Kingdom
# 23                 Americas             Brazil
# 24                     Asia              Japan
# 25                     Asia             Taiwan
# 26                 Americas             Canada
# 27                     Asia              India
# 28                 Americas      United States
# 29                   Europe            Belgium
# ...                     ...                ...
# 499970             Americas      United States
# 499971             Americas      United States
# 499972                 Asia              Japan
# 499973               Europe             Sweden
# 499974             Americas      United States
# 499975               Africa       South Africa
# 499976             Americas      United States
# 499977               Europe            Hungary
# 499978             Americas      United States
# 499979             Americas      United States
# 499980             Americas      United States
# 499981             Americas      United States
# 499982                 Asia              India
# 499983                 Asia              India
# 499984             Americas      United States
# 499985                 Asia              Japan
# 499986             Americas             Canada
# 499987                 Asia              Japan
# 499988              Oceania          Australia
# 499989             Americas      United States
# 499990                 Asia          Singapore
# 499991             Americas      United States
# 499992               Europe             France
# 499993               Africa            Senegal
# 499994               Europe     United Kingdom
# 499995             Americas      United States
# 499996             Americas      United States
# 499997               Europe        Netherlands
# 499998                 Asia             Taiwan
# 499999                 Asia              India
#
#                          geoNetwork.metro geoNetwork.networkDomain  \
# 0           not available in demo dataset                (not set)
# 1       San Francisco-Oakland-San Jose CA                (not set)
# 2           not available in demo dataset      windjammercable.net
# 3           not available in demo dataset          unknown.unknown
# 4           not available in demo dataset    prod-infinitum.com.mx
# 5       San Francisco-Oakland-San Jose CA          unknown.unknown
# 6                                  London                (not set)
# 7           not available in demo dataset           fullrate.ninja
# 8                               (not set)        uninet-ide.com.mx
# 9           not available in demo dataset                (not set)
# 10          not available in demo dataset          unknown.unknown
# 11          not available in demo dataset             gavlenet.com
# 12          not available in demo dataset                  bhn.net
# 13                              (not set)                  att.net
# 14          not available in demo dataset                (not set)
# 15          not available in demo dataset              virginm.net
# 16          not available in demo dataset                (not set)
# 17          not available in demo dataset        btcentralplus.com
# 18                              (not set)          unknown.unknown
# 19          not available in demo dataset                 pldt.net
# 20          not available in demo dataset                orange.sk
# 21          not available in demo dataset              virginm.net
# 22          not available in demo dataset              virginm.net
# 23          not available in demo dataset          unknown.unknown
# 24                               JP_KANTO        panda-world.ne.jp
# 25          not available in demo dataset              nthu.edu.tw
# 26          not available in demo dataset                 start.ca
# 27          not available in demo dataset                    ac.in
# 28                         Los Angeles CA             cogentco.com
# 29                              (not set)                (not set)
# ...                                   ...                      ...
# 499970      not available in demo dataset                (not set)
# 499971                  Seattle-Tacoma WA                (not set)
# 499972      not available in demo dataset             so-net.ne.jp
# 499973      not available in demo dataset                telia.com
# 499974      not available in demo dataset      comcastbusiness.net
# 499975      not available in demo dataset          unknown.unknown
# 499976      not available in demo dataset          unknown.unknown
# 499977      not available in demo dataset             broadband.hu
# 499978                         Atlanta GA                  att.net
# 499979      not available in demo dataset                (not set)
# 499980      not available in demo dataset               allcom.net
# 499981      not available in demo dataset               utexas.edu
# 499982                          (not set)                (not set)
# 499983                          (not set)                (not set)
# 499984      not available in demo dataset                (not set)
# 499985                           JP_KANTO       arteria-hikari.net
# 499986      not available in demo dataset                   ubc.ca
# 499987      not available in demo dataset               mesh.ad.jp
# 499988                          (not set)          unknown.unknown
# 499989                     San Antonio TX            sbcglobal.net
# 499990                          (not set)                (not set)
# 499991                        New York NY                (not set)
# 499992                          (not set)                  sfr.net
# 499993      not available in demo dataset                (not set)
# 499994      not available in demo dataset          unknown.unknown
# 499995                     Los Angeles CA                 ucla.edu
# 499996      not available in demo dataset                (not set)
# 499997      not available in demo dataset                 ziggo.nl
# 499998      not available in demo dataset                hinet.net
# 499999      not available in demo dataset          unknown.unknown
#
#                     geoNetwork.region geoNetwork.subContinent totals.bounces  \
# 0       not available in demo dataset          Western Europe              1
# 1                          California        Northern America            NaN
# 2       not available in demo dataset        Northern America            NaN
# 3       not available in demo dataset            Western Asia            NaN
# 4       not available in demo dataset         Central America            NaN
# 5                          California        Northern America            NaN
# 6                             England         Northern Europe            NaN
# 7       not available in demo dataset         Northern Europe            NaN
# 8                         Mexico City         Central America            NaN
# 9       not available in demo dataset          Western Europe            NaN
# 10      not available in demo dataset         Northern Europe            NaN
# 11      not available in demo dataset         Northern Europe            NaN
# 12      not available in demo dataset        Northern America            NaN
# 13                             Nevada        Northern America            NaN
# 14      not available in demo dataset        Northern America            NaN
# 15      not available in demo dataset         Northern Europe            NaN
# 16      not available in demo dataset           Southern Asia            NaN
# 17      not available in demo dataset         Northern Europe            NaN
# 18                           Brussels          Western Europe            NaN
# 19      not available in demo dataset          Southeast Asia            NaN
# 20      not available in demo dataset          Eastern Europe            NaN
# 21      not available in demo dataset         Northern Europe            NaN
# 22      not available in demo dataset         Northern Europe            NaN
# 23      not available in demo dataset           South America            NaN
# 24                              Tokyo            Eastern Asia            NaN
# 25      not available in demo dataset            Eastern Asia            NaN
# 26      not available in demo dataset        Northern America            NaN
# 27      not available in demo dataset           Southern Asia            NaN
# 28                         California        Northern America            NaN
# 29                           Brussels          Western Europe            NaN
# ...                               ...                     ...            ...
# 499970  not available in demo dataset        Northern America              1
# 499971                     Washington        Northern America              1
# 499972  not available in demo dataset            Eastern Asia              1
# 499973  not available in demo dataset         Northern Europe              1
# 499974  not available in demo dataset        Northern America              1
# 499975  not available in demo dataset         Southern Africa              1
# ...                           ...                          ...
# 499970                      False                        False
# 499971                      False                        False
# 499972                      False                        False
# 499973                      False                        False
# 499974                      False                        False
# 499975                      False                        False
# 499976                      False                        False
# 499977                      False                        False
# 499978                      False                        False
# 499979                      False                        False
# 499980                      False                        False
# 499981                      False                        False
# 499982                      False                        False
# 499983                      False                        False
# 499984                      False                        False
# 499985                      False                        False
# 499986                      False                        False
# 499987                      False                        False
# 499988                      False                        False
# 499989                      False                        False
# 499990                      False                        False
# 499991                      False                        False
# 499992                      False                        False
# 499993                      False                        False
# 499994                      False                        False
# 499995                      False                        False
# 499996                      False                        False
# 499997                      False                        False
# 499998                      False                        False
# 499999                      False                        False
#
#         visitStartTimeElapsed
# 0                  1508198450
# 1                  1508176307
# 2                  1508201613
# 3                  1508169851
# 4                  1508190552
# 5                  1508196701
# 6                  1508152478
# 7                  1508206208
# 8                  1508207516
# 9                  1508165159
# 10                 1508157285
# 11                 1508160120
# 12                 1508177658
# 13                 1508166431
# 14                 1508174145
# 15                 1508197277
# 16                 1508177911
# 17                 1508153337
# 18                 1508160406
# 19                 1508160304
# 20                 1508142274
# 21                 1508170914
# 22                 1508165231
# 23                 1508167897
# 24                 1508150872
# 25                 1508223135
# 26                 1508203074
# 27                 1508183432
# 28                 1508179019
# 29                 1508160016
# ...                       ...
# 499970             1511125054
# 499971             1511091873
# 499972             1511093889
# 499973             1511117186
# 499974             1511114018
# 499975             1511127637
# 499976             1511105637
# 499977             1511127247
# 499978             1511160243
# 499979             1511125621
# 499980             1511125105
# 499981             1511155749
# 499982             1511078500
# 499983             1511160346
# 499984             1511097703
# 499985             1511143022
# 499986             1511090704
# 499987             1511131971
# 499988             1511161564
# 499989             1511158596
# 499990             1511095410
# 499991             1511113152
# 499992             1511127482
# 499993             1511137125
# 499994             1511137040
# 499995             1511131859
# 499996             1511153899
# 499997             1511113733
# 499998             1511114113
# 499999             1511121537
#
# [500000 rows x 62 columns]

# %%
df_raw['totals.totalTransactionRevenue'].fillna(0, inplace=True)
df_raw['totals.transactions'].fillna(0, inplace=True)
df_raw['totals.transactions'] = df_raw['totals.transactions'].astype('int8')

# %%
df_test["visitStartTime"] = pd.to_datetime(df_test["visitStartTime"], infer_datetime_format=True, unit="s")
df_test["date"] = pd.to_datetime(df_test["date"], infer_datetime_format=True, format="%Y%m%d")
add_datepart(df_test, 'date')
add_datepart(df_test, 'visitStartTime')
# Out:
#        channelGrouping        fullVisitorId     visitId  visitNumber  \
# 0       Organic Search  7460955084541987166  1526099341            2
# 1               Direct   460252456180441002  1526064483          -90
# 2       Organic Search  3461808543879602873  1526067157            2
# 3               Direct   975129477712150630  1526107551            4
# 4       Organic Search  8381672768065729990  1526060254            1
# 5       Organic Search  2866297766347322467  1526061951            2
# 6               Direct  2235365487897339889  1526062356            1
# 7       Organic Search  1303090465617023038  1526078660            3
# 8           Affiliates  0459669224143241747  1526054953            1
# 9               Direct   589440789980446309  1526051458            1
# 10            Referral  5299820794845174508  1526087937            2
# 11            Referral  7414906446453226824  1526051687            1
# 12              Direct  4063440620410560213  1526081933            1
# 13            Referral  3326540121689239742  1526068491            1
# 14      Organic Search  7713658643915819491  1526040686            1
# 15            Referral  7437323504893211921  1526087525            1
# 16            Referral  9553181489247767015  1526044676            1
# 17      Organic Search  4605774125139978152  1526041980            1
# 18      Organic Search  2400060996995525389  1526039044            1
# 19              Direct  3524623036868660621  1526058521            1
# 20      Organic Search  8935547912864718155  1526051837            1
# 21              Direct  6535191149463473748  1526048442            2
# 22         Paid Search  3099959025206912558  1526093764            1
# 23      Organic Search  7731199528001457558  1526033353           26
# 24      Organic Search  6228341191093238277  1526071685            1
# 25      Organic Search  1237026169588168141  1526052461            1
# 26      Organic Search  7075733582376632838  1526095788            1
# 27      Organic Search   713763283771900341  1526092332            1
# 28      Organic Search  8013368769702493385  1526044519            1
# 29            Referral  3002134698450238670  1526053964            2
# ...                ...                  ...         ...          ...
# 401559  Organic Search  8296193359762371369  1536373151            1
# 401560          Direct  1549017024945607206  1536320118            4
# 401561  Organic Search  5459888270755778961  1536354901            1
# 401562  Organic Search  7379506395045720633  1536338786            1
# 401563  Organic Search  7419481068364332076  1536360312            3
# 401564  Organic Search  9714609708290648394  1536337838            1
# 401565  Organic Search  1949892957619427768  1536307918            1
# 401566  Organic Search  0834769620164416301  1536330584            1
# 401567  Organic Search  0046164646319016449  1536320049            1
# 401568  Organic Search  7920234542327870972  1536380435            1
# 401569          Direct  0589602066910896417  1536305184            2
# 401570          Social  1929938934498315267  1536375186            2
# 401571          Social  7625151920601736221  1536304557            1
# 401572          Social   918425270430376871  1536320565            1
# 401573          Social  9370858930262202604  1536352380            1
# 401574          Social  7606049174415801656  1536370000            1
# 401575          Social   064957673008594353  1536365496            1
# 401576     Paid Search   749993830466975332  1536378971            2
# 401577     Paid Search   864549576977417799  1536375467            1
# 401578     Paid Search  4034147449948670127  1536335821            1
# 401579  Organic Search  4669273808148710583  1536367342            1
# 401580  Organic Search  0131487681572776544  1536317560            2
# 401581          Direct  6430704158335065330  1536376039            1
# 401582          Direct   038602058839816526  1536342427            1
# 401583  Organic Search  0968252650203166789  1536383313            1
# 401584  Organic Search  6701149525099562370  1536353803            1
# 401585  Organic Search  6154541330147351453  1536388075            1
# 401586  Organic Search  6013469762773705448  1536351791            3
# 401587  Organic Search  4565378823441900999  1536340217            1
# 401588          Direct  3875690118293601911  1536331301            1
#
#            device.browser device.deviceCategory  device.isMobile  \
# 0                  Chrome                mobile             True
# 1                  Chrome               desktop            False
# 2                  Chrome               desktop            False
# 3                  Chrome                mobile             True
# 4       Internet Explorer                tablet             True
# 5                  Chrome               desktop            False
# 6                  Chrome                mobile             True
# 7                  Chrome               desktop            False
# 8         Safari (in-app)                tablet             True
# 9                    Edge               desktop            False
# 10                 Chrome               desktop            False
# 11                 Chrome               desktop            False
# 12                 Chrome               desktop            False
# 13                 Chrome               desktop            False
# 14                 Safari               desktop            False
# 15                 Chrome               desktop            False
# 16                 Chrome               desktop            False
# 17                 Chrome               desktop            False
# 18                 Chrome               desktop            False
# 19                 Chrome               desktop            False
# 20                 Chrome               desktop            False
# 21                Firefox               desktop            False
# 22                   Edge               desktop            False
# 23                 Chrome               desktop            False
# 24                 Chrome               desktop            False
# 25                 Safari                mobile             True
# 26                 Safari                mobile             True
# 27                 Chrome                mobile             True
# 28                 Chrome               desktop            False
# 29                 Chrome               desktop            False
# ...                   ...                   ...              ...
# 401559             Safari                mobile             True
# 401560             Safari                mobile             True
# 401561             Chrome               desktop            False
# 401562             Safari                tablet             True
# 401563             Chrome               desktop            False
# 401564             Safari               desktop            False
# 401565             Chrome               desktop            False
# 401566             Chrome               desktop            False
# 401567             Chrome               desktop            False
# 401568             Chrome                mobile             True
# 401569             Chrome               desktop            False
# 401570             Chrome               desktop            False
# 401571             Chrome               desktop            False
# 401572             Chrome               desktop            False
# 401573             Safari               desktop            False
# 401574             Chrome               desktop            False
# 401575             Chrome                mobile             True
# 401576             Safari                mobile             True
# 401577             Safari                mobile             True
# 401578             Chrome                mobile             True
# 401579             Chrome               desktop            False
# 401580             Chrome               desktop            False
# 401581             Chrome               desktop            False
# 401582             Chrome                mobile             True
# 401583             Chrome               desktop            False
# 401584             Chrome                mobile             True
# 401585             Chrome               desktop            False
# 401586            Firefox               desktop            False
# 401587             Chrome               desktop            False
# 401588             Chrome                mobile             True
#
#        device.operatingSystem                geoNetwork.city  \
# 0                     Android                      (not set)
# 1                   Macintosh                  San Francisco
# 2                   Chrome OS  not available in demo dataset
# 3                         iOS                        Houston
# 4                     Windows                         Irvine
# 5                     Windows  not available in demo dataset
# 6                     Android                       San Jose
# 7                   Macintosh                  Mountain View
# 8                         iOS  not available in demo dataset
# 9                     Windows                         Madrid
# 10                      Linux                       Kirkland
# 11                  Chrome OS                      Ann Arbor
# 12                    Windows  not available in demo dataset
# 13                      Linux                      Ann Arbor
# 14                  Macintosh                         Riyadh
# 15                  Macintosh                       Shinjuku
# 16                  Macintosh                          Prato
# 17                    Windows  not available in demo dataset
# 18                  Macintosh  not available in demo dataset
# 19                  Macintosh  not available in demo dataset
# 20                  Macintosh                       New York
# 21                    Windows  not available in demo dataset
# 22                    Windows                        Redmond
# 23                    Windows  not available in demo dataset
# 24                    Windows  not available in demo dataset
# 25                        iOS  not available in demo dataset
# 26                        iOS  not available in demo dataset
# 27                        iOS  not available in demo dataset
# 28                    Windows                      Ahmedabad
# 29                    Windows                      Sunnyvale
# ...                       ...                            ...
# 401559                    iOS                      Ann Arbor
# 401560                    iOS  not available in demo dataset
# 401561                Windows  not available in demo dataset
# 401562                    iOS  not available in demo dataset
# 401563                Windows  not available in demo dataset
# 401564              Macintosh  not available in demo dataset
# 401565              Macintosh  not available in demo dataset
# 401566              Macintosh  not available in demo dataset
# 401567                Windows  not available in demo dataset
# 401568                    iOS                      Hyderabad
# 401569                Windows                      (not set)
# 401570                Windows  not available in demo dataset
# 401571                Windows  not available in demo dataset
# 401572                Windows  not available in demo dataset
# 401573              Macintosh  not available in demo dataset
# 401574                Windows                      Amsterdam
# 401575                Android  not available in demo dataset
# 401576                    iOS                  San Francisco
# 401577                    iOS  not available in demo dataset
# 401578                Android  not available in demo dataset
# 401579              Macintosh                       New York
# 401580                Windows  not available in demo dataset
# 401581                Windows  not available in demo dataset
# 401582                Android                         Mumbai
# 401583                Windows  not available in demo dataset
# 401584                Android  not available in demo dataset
# 401585                Windows  not available in demo dataset
# 401586                Windows  not available in demo dataset
# 401587              Chrome OS  not available in demo dataset
# 401588                Android  not available in demo dataset
#
#        geoNetwork.continent geoNetwork.country  \
# 0                      Asia              India
# 1                  Americas      United States
# 2                  Americas      United States
# 3                  Americas      United States
# 4                  Americas      United States
# 5                  Americas             Brazil
# 6                  Americas      United States
# 7                  Americas      United States
# 8                      Asia             Taiwan
# 9                    Europe              Spain
# 10                 Americas      United States
# 11                 Americas      United States
# 12                 Americas      United States
# 13                 Americas      United States
# 14                     Asia       Saudi Arabia
# 15                     Asia              Japan
# 16                   Europe              Italy
# 17                   Europe             Russia
# 18                   Europe     United Kingdom
# 19                 Americas      United States
# 20                 Americas      United States
# 21                 Americas      United States
# 22                 Americas      United States
# 23                 Americas      United States
# 24                 Americas      United States
# 25                 Americas      United States
# 26                 Americas      United States
# 27                 Americas      United States
# 28                     Asia              India
# 29                 Americas      United States
# ...                     ...                ...
# 401559             Americas      United States
# 401560               Europe            Belgium
# 401561             Americas      United States
# 401562             Americas      United States
# 401563               Europe            Germany
# 401564               Europe     United Kingdom
# 401565               Europe            Denmark
# 401566             Americas      United States
# 401567               Europe            Germany
# 401568                 Asia              India
# 401569                 Asia             Taiwan
# 401570              Oceania          Australia
# 401571                 Asia         Azerbaijan
# 401572               Europe             France
# 401573             Americas      United States
# 401574               Europe        Netherlands
# 401575             Americas      United States
# 401576             Americas      United States
# 401577             Americas      United States
# 401578             Americas      United States
# 401579             Americas      United States
# 401580             Americas      United States
# 401581                 Asia              Japan
# 401582                 Asia              India
# 401583             Americas      United States
# 401584               Europe     United Kingdom
# 401585             Americas      United States
# 401586               Europe             Greece
# 401587             Americas      United States
# 401588                 Asia           Pakistan
#
#                          geoNetwork.metro geoNetwork.networkDomain  \
# 0                               (not set)          unknown.unknown
# 1       San Francisco-Oakland-San Jose CA                (not set)
# 2           not available in demo dataset  onlinecomputerworks.com
# 3                              Houston TX                (not set)
# 4                          Los Angeles CA                      com
# 5           not available in demo dataset           vivozap.com.br
# 6       San Francisco-Oakland-San Jose CA               tmodns.net
# 7       San Francisco-Oakland-San Jose CA                (not set)
# 8           not available in demo dataset                hinet.net
# 9                               (not set)                  urjc.es
# 10                      Seattle-Tacoma WA                (not set)
# 11                             Detroit MI                (not set)
# 12          not available in demo dataset                  bhn.net
# 13                             Detroit MI                (not set)
# 14                              (not set)                (not set)
# 15                               JP_KANTO                (not set)
# 16                              (not set)            consiagnet.it
# 17          not available in demo dataset             ertelecom.ru
# 18          not available in demo dataset                (not set)
# 19          not available in demo dataset             stanford.edu
# 20                            New York NY                (not set)
# 21          not available in demo dataset                (not set)
# 22                      Seattle-Tacoma WA                (not set)
# 23          not available in demo dataset              comcast.net
# 24          not available in demo dataset                   rr.com
# 25          not available in demo dataset                   rr.com
# 26          not available in demo dataset          abbnebraska.com
# 27          not available in demo dataset                (not set)
# 28                              (not set)          unknown.unknown
# 29      San Francisco-Oakland-San Jose CA                (not set)
# ...                                   ...                      ...
# 401559                         Detroit MI                myvzw.com
# 401560      not available in demo dataset                (not set)
# 401561      not available in demo dataset                (not set)
# 401562      not available in demo dataset          centurylink.net
# 401563      not available in demo dataset                (not set)
# 401564      not available in demo dataset                (not set)
# 401565      not available in demo dataset                  tdc.net
# 401566      not available in demo dataset                (not set)
# 401567      not available in demo dataset           unitymedia.biz
# 401568                          (not set)               pol.net.in
# 401569                          (not set)                hinet.net
# 401570      not available in demo dataset          unknown.unknown
# 401571      not available in demo dataset          unknown.unknown
# 401572      not available in demo dataset           numericable.fr
# 401573      not available in demo dataset                (not set)
# 401574                          (not set)                   org.tr
# 401575      not available in demo dataset              verizon.net
# 401576  San Francisco-Oakland-San Jose CA                (not set)
# 401577      not available in demo dataset              comcast.net
# 401578      not available in demo dataset            optonline.net
# 401579                        New York NY              verizon.net
# 401580      not available in demo dataset              verizon.net
# 401581      not available in demo dataset                  zoot.jp
# 401582                          (not set)              vodafone.in
# 401583      not available in demo dataset           windstream.net
# 401584      not available in demo dataset                (not set)
# 401585      not available in demo dataset                (not set)
# 401586      not available in demo dataset                (not set)
# 401587      not available in demo dataset                (not set)
# 401588      not available in demo dataset         worldcall.net.pk
#
#                     geoNetwork.region geoNetwork.subContinent totals.bounces  \
# 0                               Delhi           Southern Asia            NaN
# 1                          California        Northern America            NaN
# 2       not available in demo dataset        Northern America            NaN
# 3                               Texas        Northern America            NaN
# 4                          California        Northern America            NaN
# 5       not available in demo dataset           South America            NaN
# 6                          California        Northern America            NaN
# 7                          California        Northern America            NaN
# 8       not available in demo dataset            Eastern Asia            NaN
# 9                              Madrid         Southern Europe            NaN
# 10                         Washington        Northern America            NaN
# 11                           Michigan        Northern America            NaN
# 12      not available in demo dataset        Northern America            NaN
# 13                           Michigan        Northern America            NaN
# 14                    Riyadh Province            Western Asia            NaN
# 15                              Tokyo            Eastern Asia            NaN
# 16                            Tuscany         Southern Europe            NaN
# 17      not available in demo dataset          Eastern Europe            NaN
# 18      not available in demo dataset         Northern Europe            NaN
# 19      not available in demo dataset        Northern America            NaN
# 20                           New York        Northern America            NaN
# 21      not available in demo dataset        Northern America            NaN
# 22                         Washington        Northern America            NaN
# 23      not available in demo dataset        Northern America            NaN
# 24      not available in demo dataset        Northern America            NaN
# 25      not available in demo dataset        Northern America            NaN
# 26      not available in demo dataset        Northern America            NaN
# 27      not available in demo dataset        Northern America            NaN
# 28                            Gujarat           Southern Asia            NaN
# 29                         California        Northern America            NaN
# ...                               ...                     ...            ...
# 401559                       Michigan        Northern America            NaN
# 401560  not available in demo dataset          Western Europe            NaN
# 401561  not available in demo dataset        Northern America            NaN
# 401562  not available in demo dataset        Northern America            NaN
# 401563  not available in demo dataset          Western Europe            NaN
# 401564  not available in demo dataset         Northern Europe            NaN
# 401565  not available in demo dataset         Northern Europe            NaN
# 401566  not available in demo dataset        Northern America            NaN
# 401567  not available in demo dataset          Western Europe            NaN
# 401568                      Telangana           Southern Asia            NaN
# 401569                    Taipei City            Eastern Asia            NaN
# 401570  not available in demo dataset             Australasia            NaN
# 401571  not available in demo dataset            Western Asia            NaN
# 401572  not available in demo dataset          Western Europe            NaN
# 401573  not available in demo dataset        Northern America            NaN
# 401574                  North Holland          Western Europe            NaN
# 401575  not available in demo dataset        Northern America            NaN
# 401576                     California        Northern America            NaN
# 401577  not available in demo dataset        Northern America            NaN
# 401578  not available in demo dataset        Northern America            NaN
# 401579                       New York        Northern America            NaN
# 401580  not available in demo dataset        Northern America            NaN
# 401581  not available in demo dataset            Eastern Asia            NaN
# 401582                    Maharashtra           Southern Asia            NaN
# 401583  not available in demo dataset        Northern America            NaN
# 401584  not available in demo dataset         Northern Europe            NaN
# 401585  not available in demo dataset        Northern America            NaN
# 401586  not available in demo dataset         Southern Europe            NaN
# 401587  not available in demo dataset        Northern America            NaN
# 401588  not available in demo dataset           Southern Asia            NaN
#
#        totals.hits totals.newVisits totals.pageviews totals.sessionQualityDim  \
# 0                4              NaN                3                        1
# 1                4              NaN                3                        1
# 2                4              NaN                3                        1
# 3                5              NaN                4                        1
# 4                5                1                4                        1
# 5                5              NaN                4                        1
# 6                5                1                4                        1
# 7                5              NaN                4                        1
# 8                5                1                3                        1
# 9                5                1                3                        1
# 10               5              NaN                3                        1
# 11               5                1                4                        8
# 12               5                1                4                        4
# 13               5                1                4                        1
# 14               5                1                4                        1
# 15               5                1                4                        1
# 16               5                1                4                        1
# 17               5                1                3                        1
# 18               5                1                3                        1
# 19               5                1                3                        3
# 20               5                1                3                        1
# 21               5              NaN                3                        1
# 22               5                1                4                        1
# 23               5              NaN                3                        2
# 24               5                1                3                        1
# 25               5                1                3                        1
# 26               5                1                4                        1
# 27               5                1                4                        1
# 28               5                1                3                        1
# 29               5              NaN                3                        1
# ...            ...              ...              ...                      ...
# 401559           2                1                2                        1
# 401560           2              NaN                2                        1
# 401561           2                1                2                        1
# 401562           2                1                2                        1
# 401563           2              NaN                2                        1
# 401564           2                1                2                        1
# 401565           2                1                2                        1
# 401566           2                1                2                        1
# 401567           2                1                2                        1
# 401568           2                1                2                        1
# 401569           2              NaN                2                        1
# 401570           2              NaN                2                        1
# 401571           2                1                2                        1
# 401572           2                1                2                        1
# 401573           2                1                2                        1
# 401574           2                1                2                        1
# 401575           2                1                2                        1
# 401576           3              NaN                3                        2
# 401577           3                1                3                        1
# 401578           3                1                3                        2
# 401579           3                1                3                        1
# 401580           3              NaN                3                        2
# 401581           3                1                3                        1
# 401582           3                1                3                        1
# 401583           3                1                3                        1
# 401584           3                1                3                        1
# 401585           3                1                3                        1
# 401586           3              NaN                3                        1
# 401587           3                1                3                        1
# 401588           3                1                3                        1
#
#        totals.timeOnSite totals.totalTransactionRevenue  \
# 0                    973                            NaN
# 1                     49                            NaN
# 2                     24                            NaN
# 3                     25                            NaN
# 4                     49                            NaN
# 5                    120                            NaN
# 6                     58                            NaN
# 7                     56                            NaN
# 8                     57                            NaN
# 9                     22                            NaN
# 10                    28                            NaN
# 11                   419                            NaN
# 12                   634                            NaN
# 13                    42                            NaN
# 14                   741                            NaN
# 15                    64                            NaN
# 16                    36                            NaN
# 17                    15                            NaN
# 18                     7                            NaN
# 19                   825                            NaN
# 20                    55                            NaN
# 21                    26                            NaN
# 22                     9                            NaN
# 23                     6                            NaN
# 24                   292                            NaN
# 25                    67                            NaN
# 26                   238                            NaN
# 27                    73                            NaN
# 28                    56                            NaN
# 29                    13                            NaN
# ...                  ...                            ...
# 401559                26                            NaN
# 401560              1467                            NaN
# 401561                27                            NaN
# 401562                34                            NaN
# 401563                23                            NaN
# 401564                20                            NaN
# 401565                47                            NaN
# 401566                53                            NaN
# 401567               221                            NaN
# 401568                45                            NaN
# 401569                29                            NaN
# 401570                41                            NaN
# 401571               117                            NaN
# 401572                78                            NaN
# 401573                19                            NaN
# 401574                98                            NaN
# 401575                 6                            NaN
# 401576               103                            NaN
# 401577                35                            NaN
# 401578                24                            NaN
# 401579                64                            NaN
# 401580                59                            NaN
# 401581               106                            NaN
# 401582                99                            NaN
# 401583                78                            NaN
# 401584               111                            NaN
# 401585                10                            NaN
# 401586                63                            NaN
# 401587                64                            NaN
# 401588                17                            NaN
#
#        totals.transactionRevenue totals.transactions  \
# 0                            NaN                 NaN
# 1                            NaN                 NaN
# 2                            NaN                 NaN
# 3                            NaN                 NaN
# 4                            NaN                 NaN
# 5                            NaN                 NaN
# 6                            NaN                 NaN
# 7                            NaN                 NaN
# 8                            NaN                 NaN
# 9                            NaN                 NaN
# 10                           NaN                 NaN
# 11                           NaN                 NaN
# 12                           NaN                 NaN
# 13                           NaN                 NaN
# 14                           NaN                 NaN
# 15                           NaN                 NaN
# 16                           NaN                 NaN
# 17                           NaN                 NaN
# 18                           NaN                 NaN
# 19                           NaN                 NaN
# 20                           NaN                 NaN
# 21                           NaN                 NaN
# 22                           NaN                 NaN
# 23                           NaN                 NaN
# 24                           NaN                 NaN
# 25                           NaN                 NaN
# 26                           NaN                 NaN
# 27                           NaN                 NaN
# 28                           NaN                 NaN
# 29                           NaN                 NaN
# ...                          ...                 ...
# 401559                       NaN                 NaN
# 401560                       NaN                 NaN
# 401561                       NaN                 NaN
# 401562                       NaN                 NaN
# 401563                       NaN                 NaN
# 401564                       NaN                 NaN
# 401565                       NaN                 NaN
# 401566                       NaN                 NaN
# 401567                       NaN                 NaN
# 401568                       NaN                 NaN
# 401569                       NaN                 NaN
# 401570                       NaN                 NaN
# 401571                       NaN                 NaN
# 401572                       NaN                 NaN
# 401573                       NaN                 NaN
# 401574                       NaN                 NaN
# 401575                       NaN                 NaN
# 401576                       NaN                 NaN
# 401577                       NaN                 NaN
# 401578                       NaN                 NaN
# 401579                       NaN                 NaN
# 401580                       NaN                 NaN
# 401581                       NaN                 NaN
# 401582                       NaN                 NaN
# 401583                       NaN                 NaN
# 401584                       NaN                 NaN
# 401585                       NaN                 NaN
# 401586                       NaN                 NaN
# 401587                       NaN                 NaN
# 401588                       NaN                 NaN
#
#                trafficSource.adContent  \
# 0                            (not set)
# 1                            (not set)
# 2                            (not set)
# 3                            (not set)
# 4                            (not set)
# 5                            (not set)
# 6                            (not set)
# 7                            (not set)
# 8                            (not set)
# 9                            (not set)
# 10                           (not set)
# 11                           (not set)
# 12                           (not set)
# 13                           (not set)
# 14                           (not set)
# 15                           (not set)
# 16                           (not set)
# 17                           (not set)
# 18                           (not set)
# 19                           (not set)
# 20                           (not set)
# 21                           (not set)
# 22                           (not set)
# 23                           (not set)
# 24                           (not set)
# 25                           (not set)
# 26                           (not set)
# 27                           (not set)
# 28                           (not set)
# 29                           (not set)
# ...                                ...
# 401559                       (not set)
# 401560                       (not set)
# 401561                       (not set)
# 401562                       (not set)
# 401563                       (not set)
# 401564                       (not set)
# 401565                       (not set)
# 401566                       (not set)
# 401567                       (not set)
# 401568                       (not set)
# 401569                       (not set)
# 401570                       (not set)
# 401571                       (not set)
# 401572                       (not set)
# 401573                       (not set)
# 401574                       (not set)
# 401575                       (not set)
# 401576   Google Merchandise Collection
# 401577  YouTube Merchandise Collection
# 401578   Google Merchandise Collection
# 401579                       (not set)
# 401580                       (not set)
# 401581                       (not set)
# 401582                       (not set)
# 401583                       (not set)
# 401584                       (not set)
# 401585                       (not set)
# 401586                       (not set)
# 401587                       (not set)
# 401588                       (not set)
#
#        trafficSource.adwordsClickInfo.adNetworkType  \
# 0                                               NaN
# 1                                               NaN
# 2                                               NaN
# 3                                               NaN
# 4                                               NaN
# 5                                               NaN
# 6                                               NaN
# 7                                               NaN
# 8                                               NaN
# 9                                               NaN
# 10                                              NaN
# 11                                              NaN
# 12                                              NaN
# 13                                              NaN
# 14                                              NaN
# 15                                              NaN
# 16                                              NaN
# 17                                              NaN
# 18                                              NaN
# 19                                              NaN
# 20                                              NaN
# 21                                              NaN
# 22                                              NaN
# 23                                              NaN
# 24                                              NaN
# 25                                              NaN
# 26                                              NaN
# 27                                              NaN
# 28                                              NaN
# 29                                              NaN
# ...                                             ...
# 401559                                          NaN
# 401560                                          NaN
# 401561                                          NaN
# 401562                                          NaN
# 401563                                          NaN
# 401564                                          NaN
# 401565                                          NaN
# 401566                                          NaN
# 401567                                          NaN
# 401568                                          NaN
# 401569                                          NaN
# 401570                                          NaN
# 401571                                          NaN
# 401572                                          NaN
# 401573                                          NaN
# 401574                                          NaN
# 401575                                          NaN
# 401576                                Google Search
# 401577                                Google Search
# 401578                                Google Search
# 401579                                          NaN
# 401580                                          NaN
# 401581                                          NaN
# 401582                                          NaN
# 401583                                          NaN
# 401584                                          NaN
# 401585                                          NaN
# 401586                                          NaN
# 401587                                          NaN
# 401588                                          NaN
#
#                      trafficSource.adwordsClickInfo.gclId  \
# 0                                                     NaN
# 1                                                     NaN
# 2                                                     NaN
# 3                                                     NaN
# 4                                                     NaN
# 5                                                     NaN
# 6                                                     NaN
# 7                                                     NaN
# 8                                                     NaN
# 9                                                     NaN
# 10                                                    NaN
# 11                                                    NaN
# 12                                                    NaN
# 13                                                    NaN
# 14                                                    NaN
# 15                                                    NaN
# 16                                                    NaN
# 17                                                    NaN
# 18                                                    NaN
# 19                                                    NaN
# 20                                                    NaN
# 21                                                    NaN
# 22                                                    NaN
# 23                                                    NaN
# 24                                                    NaN
# 25                                                    NaN
# 26                                                    NaN
# 27                                                    NaN
# 28                                                    NaN
# 29                                                    NaN
# ...                                                   ...
# 401559                                                NaN
# 401560                                                NaN
# 401561                                                NaN
# 401562                                                NaN
# 401563                                                NaN
# 401564                                                NaN
# 401565                                                NaN
# 401566                                                NaN
# 401567                                                NaN
# 401568                                                NaN
# 401569                                                NaN
# 401570                                                NaN
# 401571                                                NaN
# 401572                                                NaN
# 401573                                                NaN
# 401574                                                NaN
# 401575                                                NaN
# 401576  Cj0KCQjww8jcBRDZARIsAJGCSGtYmL2dmLf41VVcMtOcKe...
# 401577  Cj0KCQjww8jcBRDZARIsAJGCSGu9iBiNJec3LbKxlwgLfb...
# 401578  Cj0KCQjww8jcBRDZARIsAJGCSGtSIW2kSrxOC1rqhRR257...
# 401579                                                NaN
# 401580                                                NaN
# 401581                                                NaN
# 401582                                                NaN
# 401583                                                NaN
# 401584                                                NaN
# 401585                                                NaN
# 401586                                                NaN
# 401587                                                NaN
# 401588                                                NaN
#
#        trafficSource.adwordsClickInfo.isVideoAd  \
# 0                                           NaN
# 1                                           NaN
# 2                                           NaN
# 3                                           NaN
# 4                                           NaN
# 5                                           NaN
# 6                                           NaN
# 7                                           NaN
# 8                                           NaN
# 9                                           NaN
# 10                                          NaN
# 11                                          NaN
# 12                                          NaN
# 13                                          NaN
# 14                                          NaN
# 15                                          NaN
# 16                                          NaN
# 17                                          NaN
# ...
# 401574                  8                        5                      251
# 401575                  8                        5                      251
# 401576                  8                        5                      251
# 401577                  8                        5                      251
# 401578                  7                        4                      250
# 401579                  8                        5                      251
# 401580                  7                        4                      250
# 401581                  8                        5                      251
# 401582                  7                        4                      250
# 401583                  8                        5                      251
# 401584                  7                        4                      250
# 401585                  8                        5                      251
# 401586                  7                        4                      250
# 401587                  7                        4                      250
# 401588                  7                        4                      250
#
#         visitStartTimeIs_month_end  visitStartTimeIs_month_start  \
# 0                            False                         False
# 1                            False                         False
# 2                            False                         False
# 3                            False                         False
# 4                            False                         False
# 5                            False                         False
# 6                            False                         False
# 7                            False                         False
# 8                            False                         False
# 9                            False                         False
# 10                           False                         False
# 11                           False                         False
# 12                           False                         False
# 13                           False                         False
# 14                           False                         False
# 15                           False                         False
# 16                           False                         False
# 17                           False                         False
# 18                           False                         False
# 19                           False                         False
# 20                           False                         False
# 21                           False                         False
# 22                           False                         False
# 23                           False                         False
# 24                           False                         False
# 25                           False                         False
# 26                           False                         False
# 27                           False                         False
# 28                           False                         False
# 29                           False                         False
# ...                            ...                           ...
# 401559                       False                         False
# 401560                       False                         False
# 401561                       False                         False
# 401562                       False                         False
# 401563                       False                         False
# 401564                       False                         False
# 401565                       False                         False
# 401566                       False                         False
# 401567                       False                         False
# 401568                       False                         False
# 401569                       False                         False
# 401570                       False                         False
# 401571                       False                         False
# 401572                       False                         False
# 401573                       False                         False
# 401574                       False                         False
# 401575                       False                         False
# 401576                       False                         False
# 401577                       False                         False
# 401578                       False                         False
# 401579                       False                         False
# 401580                       False                         False
# 401581                       False                         False
# 401582                       False                         False
# 401583                       False                         False
# 401584                       False                         False
# 401585                       False                         False
# 401586                       False                         False
# 401587                       False                         False
# 401588                       False                         False
#
#         visitStartTimeIs_quarter_end  visitStartTimeIs_quarter_start  \
# 0                              False                           False
# 1                              False                           False
# 2                              False                           False
# 3                              False                           False
# 4                              False                           False
# 5                              False                           False
# 6                              False                           False
# 7                              False                           False
# 8                              False                           False
# 9                              False                           False
# 10                             False                           False
# 11                             False                           False
# 12                             False                           False
# 13                             False                           False
# 14                             False                           False
# 15                             False                           False
# 16                             False                           False
# 17                             False                           False
# 18                             False                           False
# 19                             False                           False
# 20                             False                           False
# 21                             False                           False
# 22                             False                           False
# 23                             False                           False
# 24                             False                           False
# 25                             False                           False
# 26                             False                           False
# 27                             False                           False
# 28                             False                           False
# 29                             False                           False
# ...                              ...                             ...
# 401559                         False                           False
# 401560                         False                           False
# 401561                         False                           False
# 401562                         False                           False
# 401563                         False                           False
# 401564                         False                           False
# 401565                         False                           False
# 401566                         False                           False
# 401567                         False                           False
# 401568                         False                           False
# 401569                         False                           False
# 401570                         False                           False
# 401571                         False                           False
# 401572                         False                           False
# 401573                         False                           False
# 401574                         False                           False
# 401575                         False                           False
# 401576                         False                           False
# 401577                         False                           False
# 401578                         False                           False
# 401579                         False                           False
# 401580                         False                           False
# 401581                         False                           False
# 401582                         False                           False
# 401583                         False                           False
# 401584                         False                           False
# 401585                         False                           False
# 401586                         False                           False
# 401587                         False                           False
# 401588                         False                           False
#
#         visitStartTimeIs_year_end  visitStartTimeIs_year_start  \
# 0                           False                        False
# 1                           False                        False
# 2                           False                        False
# 3                           False                        False
# 4                           False                        False
# 5                           False                        False
# 6                           False                        False
# 7                           False                        False
# 8                           False                        False
# 9                           False                        False
# 10                          False                        False
# 11                          False                        False
# 12                          False                        False
# 13                          False                        False
# 14                          False                        False
# 15                          False                        False
# 16                          False                        False
# 17                          False                        False
# 18                          False                        False
# 19                          False                        False
# 20                          False                        False
# 21                          False                        False
# 22                          False                        False
# 23                          False                        False
# 24                          False                        False
# 25                          False                        False
# 26                          False                        False
# 27                          False                        False
# 28                          False                        False
# 29                          False                        False
# ...                           ...                          ...
# 401559                      False                        False
# 401560                      False                        False
# 401561                      False                        False
# 401562                      False                        False
# 401563                      False                        False
# 401564                      False                        False
# 401565                      False                        False
# 401566                      False                        False
# 401567                      False                        False
# 401568                      False                        False
# 401569                      False                        False
# 401570                      False                        False
# 401571                      False                        False
# 401572                      False                        False
# 401573                      False                        False
# 401574                      False                        False
# 401575                      False                        False
# 401576                      False                        False
# 401577                      False                        False
# 401578                      False                        False
# 401579                      False                        False
# 401580                      False                        False
# 401581                      False                        False
# 401582                      False                        False
# 401583                      False                        False
# 401584                      False                        False
# 401585                      False                        False
# 401586                      False                        False
# 401587                      False                        False
# 401588                      False                        False
#
#         visitStartTimeElapsed
# 0                  1526099341
# 1                  1526064483
# 2                  1526067157
# 3                  1526107551
# 4                  1526060254
# 5                  1526061951
# 6                  1526062356
# 7                  1526078660
# 8                  1526054953
# 9                  1526051458
# 10                 1526087937
# 11                 1526051687
# 12                 1526081933
# 13                 1526068491
# 14                 1526040686
# 15                 1526087525
# 16                 1526044676
# 17                 1526041980
# 18                 1526039044
# 19                 1526058521
# 20                 1526051837
# 21                 1526048442
# 22                 1526093764
# 23                 1526033353
# 24                 1526071685
# 25                 1526052461
# 26                 1526095788
# 27                 1526092332
# 28                 1526044519
# 29                 1526053964
# ...                       ...
# 401559             1536373151
# 401560             1536320118
# 401561             1536354901
# 401562             1536338786
# 401563             1536360312
# 401564             1536337838
# 401565             1536307918
# 401566             1536330584
# 401567             1536320049
# 401568             1536380435
# 401569             1536305184
# 401570             1536375186
# 401571             1536304557
# 401572             1536320565
# 401573             1536352380
# 401574             1536370000
# 401575             1536365496
# 401576             1536378971
# 401577             1536375467
# 401578             1536335821
# 401579             1536367342
# 401580             1536317560
# 401581             1536376039
# 401582             1536342427
# 401583             1536383313
# 401584             1536353803
# 401585             1536388075
# 401586             1536351791
# 401587             1536340217
# 401588             1536331301
#
# [401589 rows x 62 columns]

# %%
from pandas.api.types import is_string_dtype, is_numeric_dtype
def train_cats(df):
    """Change any columns of strings in a panda's dataframe to a column of
    categorical values. This applies the changes inplace.
    """
    for n,c in df.items():
        if is_string_dtype(c): df[n] = c.astype('category').cat.as_ordered()

# %%
train_cats(df_raw)
train_cats(df_test)

# %%
from sklearn_pandas import DataFrameMapper
from sklearn.preprocessing import StandardScaler
import sklearn

def numericalize(df, col, name, max_n_cat):
    """ Changes the column col from a categorical type to it's integer codes.
    Parameters:
    -----------
    df: A pandas dataframe. df[name] will be filled with the integer codes from
        col.
    col: The column you wish to change into the categories.
    name: The column name you wish to insert into df. This column will hold the
        integer codes.
    max_n_cat: If col has more categories than max_n_cat it will not change the
        it to its integer codes. If max_n_cat is None, then col will always be
        converted.
    """
    if not is_numeric_dtype(col) and ( max_n_cat is None or len(col.cat.categories)>max_n_cat):
        df[name] = pd.Categorical(col).codes+1

def fix_missing(df, col, name, na_dict):
    """ Fill missing data in a column of df with the median, and add a {name}_na column
    which specifies if the data was missing.
    Parameters:
    -----------
    df: The data frame that will be changed.
    col: The column of data to fix by filling in missing data.
    name: The name of the new filled column in df.
    na_dict: A dictionary of values to create na's of and the value to insert. If
        name is not a key of na_dict the median will fill any missing data. Also
        if name is not a key of na_dict and there is no missing data in col, then
        no {name}_na column is not created.
    """
    if is_numeric_dtype(col):
        if pd.isnull(col).sum() or (name in na_dict):
            df[name+'_na'] = pd.isnull(col)
            filler = na_dict[name] if name in na_dict else col.median()
            df[name] = col.fillna(filler)
            na_dict[name] = filler
    return na_dict

def get_sample(df,n):
    """ Gets a random sample of n rows from df, without replacement.
    Parameters:
    -----------
    df: A pandas data frame, that you wish to sample from.
    n: The number of rows you wish to sample.
    Returns:
    --------
    return value: A random sample of n rows of df.
    """
    idxs = sorted(np.random.permutation(len(df))[:n])
    return df.iloc[idxs].copy()

def scale_vars(df, mapper):
    warnings.filterwarnings('ignore', category=sklearn.exceptions.DataConversionWarning)
    if mapper is None:
        map_f = [([n],StandardScaler()) for n in df.columns if is_numeric_dtype(df[n])]
        mapper = DataFrameMapper(map_f).fit(df)
    df[mapper.transformed_names_] = mapper.transform(df)
    return mapper

def proc_df(df, y_fld=None, skip_flds=None, ignore_flds=None, do_scale=False, na_dict=None,
            preproc_fn=None, max_n_cat=None, subset=None, mapper=None):
    """ proc_df takes a data frame df and splits off the response variable, and
    changes the df into an entirely numeric dataframe. For each column of df 
    which is not in skip_flds nor in ignore_flds, na values are replaced by the
    median value of the column.
    Parameters:
    -----------
    df: The data frame you wish to process.
    y_fld: The name of the response variable
    skip_flds: A list of fields that dropped from df.
    ignore_flds: A list of fields that are ignored during processing.
    do_scale: Standardizes each column in df. Takes Boolean Values(True,False)
    na_dict: a dictionary of na columns to add. Na columns are also added if there
        are any missing values.
    preproc_fn: A function that gets applied to df.
    max_n_cat: The maximum number of categories to break into dummy values, instead
        of integer codes.
    subset: Takes a random subset of size subset from df.
    mapper: If do_scale is set as True, the mapper variable
        calculates the values used for scaling of variables during training time (mean and standard deviation).
    Returns:
    [x, y, nas, mapper(optional)]
    """
    if not ignore_flds: ignore_flds=[]
    if not skip_flds: skip_flds=[]
    if subset: df = get_sample(df,subset)
    else: df = df.copy()
    ignored_flds = df.loc[:, ignore_flds]
    df.drop(ignore_flds, axis=1, inplace=True)
    if preproc_fn: preproc_fn(df)
    if y_fld is None: y = None
    else:
        if not is_numeric_dtype(df[y_fld]): df[y_fld] = pd.Categorical(df[y_fld]).codes
        y = df[y_fld].values
        skip_flds += [y_fld]
    df.drop(skip_flds, axis=1, inplace=True)

    if na_dict is None: na_dict = {}
    else: na_dict = na_dict.copy()
    na_dict_initial = na_dict.copy()
    for n,c in df.items(): na_dict = fix_missing(df, c, n, na_dict)
    if len(na_dict_initial.keys()) > 0:
        df.drop([a + '_na' for a in list(set(na_dict.keys()) - set(na_dict_initial.keys()))], axis=1, inplace=True)
    if do_scale: mapper = scale_vars(df, mapper)
    for n,c in df.items(): numericalize(df, c, n, max_n_cat)
    df = pd.get_dummies(df, dummy_na=True)
    df = pd.concat([ignored_flds, df], axis=1)
    res = [df, y, na_dict]
    if do_scale: res = res + [mapper]
    return res

# %%
x_trn, y_trn, nas = proc_df(df_raw, 'totals.transactionRevenue')

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
X_test, y_test, _ = proc_df(df_test, 'totals.transactionRevenue', nas)

# %%
m = RandomForestRegressor(n_estimators=160, max_features=0.5, n_jobs=-1, oob_score=True)

# %%
m.fit(x_trn, y_trn)
m.score(x_trn, y_trn)
# Out:
# 0.9994974118603477

# %%
sub = pd.read_csv('sample_submission_v2.csv', index_col="fullVisitorId")
sub.head()
# Out:
# C:\Users\michael\Anaconda3\envs\py36\lib\site-packages\IPython\core\interactiveshell.py:3049: DtypeWarning: Columns (0) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#                      PredictedLogRevenue
# fullVisitorId
# 0000018966949534117                  0.0
# 0000039738481224681                  0.0
# 0000073585230191399                  0.0
# 0000087588448856385                  0.0
# 0000149787903119437                  0.0

# %%
preds = m.predict(X_test)

df_actual_test = df_test.copy()

actual_predicted_revenue = preds
df_actual_test["predicted"] = actual_predicted_revenue

df_actual_test = df_actual_test[["fullVisitorId" , "predicted"]]
df_actual_test["fullVisitorId"] = df_actual_test.fullVisitorId.astype('str')
df_actual_test["predicted"] = df_actual_test.predicted.astype(np.float)
df_actual_test.index = df_actual_test.fullVisitorId
df_actual_test = df_actual_test.drop("fullVisitorId",axis=1)

# %%
final_df = df_actual_test.loc[sub.index,:]
final_df = final_df[~final_df.index.duplicated(keep='first')]
final_df = final_df.rename(index=str, columns={"predicted": "PredictedLogRevenue"})
final_df = final_df.fillna(0)
final_df.to_csv('sub.csv')
# Out:
# C:\Users\michael\Anaconda3\envs\py36\lib\site-packages\pandas\core\indexing.py:1494: FutureWarning:
# Passing list-likes to .loc or [] with any missing label will raise
# KeyError in the future, you can use .reindex() as an alternative.
#
# See the documentation here:
# https://pandas.pydata.org/pandas-docs/stable/indexing.html#deprecate-loc-reindex-listlike
#   return self._getitem_tuple(key)

# %%
import xgboost as xgb
from bayes_opt import BayesianOptimization
from sklearn.metrics import mean_squared_error

# %%
from sklearn.model_selection import train_test_split

X_train, X_val, y_train, y_val = train_test_split(x_trn, y_trn, test_size=0.25)
dtrain = xgb.DMatrix(X_train, label=y_train)
dtest = xgb.DMatrix(X_val)

# %%
def xgb_evaluate(max_depth, gamma, colsample_bytree):
    params = {'eval_metric': 'rmse',
              'max_depth': int(max_depth),
              'subsample': 0.8,
              'eta': 0.1,
              'gamma': gamma,
              'colsample_bytree': colsample_bytree}
    # Used around 1000 boosting rounds in the full model
    cv_result = xgb.cv(params, dtrain, num_boost_round=100, nfold=3)    
    
    # Bayesian optimization only knows how to maximize, not minimize, so return the negative RMSE
    return -1.0 * cv_result['test-rmse-mean'].iloc[-1]

# %%
xgb_bo = BayesianOptimization(xgb_evaluate, {'max_depth': (3, 7), 
                                             'gamma': (0, 1),
                                             'colsample_bytree': (0.3, 0.9)})
# Use the expected improvement acquisition function to handle negative numbers
# Optimally needs quite a few more initiation points and number of iterations
xgb_bo.maximize(init_points=3, n_iter=5, acq='ei')
# Out:
# |   iter    |  target   | colsam... |   gamma   | max_depth |
# -------------------------------------------------------------
# |  1        | -0.1165   |  0.4705   |  0.1845   |  3.195    |
# |  2        | -0.1109   |  0.7107   |  0.8492   |  4.476    |
# |  3        | -0.1143   |  0.5507   |  0.7306   |  4.299    |
# |  4        | -0.1093   |  0.9      |  1.0      |  7.0      |
# |  5        | -0.1093   |  0.896    |  0.9945   |  6.977    |
# |  6        | -0.1319   |  0.3088   |  0.9865   |  6.98     |
# |  7        | -0.1107   |  0.9      |  0.0      |  3.0      |
# |  8        | -0.1107   |  0.8949   |  0.9882   |  3.009    |
# =============================================================

# %%
params = xgb_bo.max['params']
params['max_depth'] = int(params['max_depth'])

# %%
model2 = xgb.train(params, dtrain, num_boost_round=250)

# Predict on testing and training set
y_pred = model2.predict(dtest)
y_train_pred = model2.predict(dtrain)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-36-f21c60845e8e> in <module>
#       6
#       7 # Report testing and training RMSE
# ----> 8 print('Validation set: ', np.sqrt(mean_squared_error(y_test, y_pred)))
#       9 print('training set: ', np.sqrt(mean_squared_error(y_train, y_train_pred)))
#
# ~\Anaconda3\envs\py36\lib\site-packages\sklearn\metrics\regression.py in mean_squared_error(y_true, y_pred, sample_weight, multioutput)
#     237     """
#     238     y_type, y_true, y_pred, multioutput = _check_reg_targets(
# --> 239         y_true, y_pred, multioutput)
#     240     check_consistent_length(y_true, y_pred, sample_weight)
#     241     output_errors = np.average((y_true - y_pred) ** 2, axis=0,
#
# ~\Anaconda3\envs\py36\lib\site-packages\sklearn\metrics\regression.py in _check_reg_targets(y_true, y_pred, multioutput)
#      73
#      74     """
# ---> 75     check_consistent_length(y_true, y_pred)
#      76     y_true = check_array(y_true, ensure_2d=False)
#      77     y_pred = check_array(y_pred, ensure_2d=False)
#
# ~\Anaconda3\envs\py36\lib\site-packages\sklearn\utils\validation.py in check_consistent_length(*arrays)
#     233     if len(uniques) > 1:
#     234         raise ValueError("Found input variables with inconsistent numbers of"
# --> 235                          " samples: %r" % [int(l) for l in lengths])
#     236
#     237
#
# ValueError: Found input variables with inconsistent numbers of samples: [401589, 125000]

# %%
# Report testing and training RMSE
print('Validation set: ', np.sqrt(mean_squared_error(y_val, y_pred)))
print('training set: ', np.sqrt(mean_squared_error(y_train, y_train_pred)))
# Out:
# Validation set:  0.10460401243740793
# training set:  0.07714914816967178

# %%
dtest_final = xgb.DMatrix(X_test)

# %%
preds = m.predict(X_test)

df_actual_test = df_test.copy()

actual_predicted_revenue = preds
df_actual_test["predicted"] = actual_predicted_revenue

df_actual_test = df_actual_test[["fullVisitorId" , "predicted"]]
df_actual_test["fullVisitorId"] = df_actual_test.fullVisitorId.astype('str')
df_actual_test["predicted"] = df_actual_test.predicted.astype(np.float)
df_actual_test.index = df_actual_test.fullVisitorId
df_actual_test = df_actual_test.drop("fullVisitorId",axis=1)

# %%
final_df = df_actual_test.loc[sub.index,:]
final_df = final_df[~final_df.index.duplicated(keep='first')]
final_df = final_df.rename(index=str, columns={"predicted": "PredictedLogRevenue"})
final_df = final_df.fillna(0)
final_df.to_csv('sub.csv')
# Out:
# C:\Users\michael\Anaconda3\envs\py36\lib\site-packages\pandas\core\indexing.py:1494: FutureWarning:
# Passing list-likes to .loc or [] with any missing label will raise
# KeyError in the future, you can use .reindex() as an alternative.
#
# See the documentation here:
# https://pandas.pydata.org/pandas-docs/stable/indexing.html#deprecate-loc-reindex-listlike
#   return self._getitem_tuple(key)
